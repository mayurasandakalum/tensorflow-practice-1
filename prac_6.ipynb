# %% [markdown]
# <a href="https://colab.research.google.com/github/mayurasandakalum/tensorflow-practice-1/blob/main/prac_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array

from tensorflow.keras.applications.resnet import ResNet101, preprocess_input
from tensorflow.keras.models import Model

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

import os
import numpy as np
import matplotlib.pyplot as plt
from random import randint
import pickle
import pandas as pd
import shutil
from scipy.stats import norm
import glob

# %%
# !wget https://public.roboflow.com/ds/zesJi02gMi?key=1hmBfyMLe1
# Out:
# --2023-08-17 10:59:40--  https://public.roboflow.com/ds/zesJi02gMi?key=1hmBfyMLe1
# Resolving public.roboflow.com (public.roboflow.com)... 151.101.1.195, 151.101.65.195
# Connecting to public.roboflow.com (public.roboflow.com)|151.101.1.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-exports/Un6Oj918VoacT7AE2ql63T5q4ft1/HShwYG6mTRhpUIvYA43Z/2/coco.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20230817%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230817T105940Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
# !unzip roboflow.zip -d /content
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/valid/000000000632_jpg.rf.bfddd0d2b86ac2bf1e80624422433f0a.jpg
#  extracting: /content/valid/000000000724_jpg.rf.905934be986f8fbaedec06c48141a84e.jpg
#  extracting: /content/valid/000000000776_jpg.rf.3a6b1375e3360b81da552a3054355666.jpg
#  extracting: /content/valid/000000000785_jpg.rf.e08b383cecfdaaa774b3780ab5e06baa.jpg
#  extracting: /content/valid/000000000802_jpg.rf.9717c2d9df9e467803d11f211672d1c4.jpg
#  extracting: /content/valid/000000000872_jpg.rf.89b5c1b297b29c118dd11a202d91d647.jpg
#  extracting: /content/valid/000000000885_jpg.rf.9bedbaab383445bc7ad6b3711224be3b.jpg
#  extracting: /content/valid/000000001000_jpg.rf.a3c5a2484544de19f7cb041f2eb43605.jpg
#  extracting: /content/valid/000000001268_jpg.rf.48cbad51033f60a71d4370e1b6cb12ca.jpg
#  extracting: /content/valid/000000001296_jpg.rf.f14cc32f4ad241ca72ebb6d350003766.jpg
# ...

# %%
# !rm roboflow.zip

# %%
path_to_dataset = r"/content/valid"

# %%
os.chdir(path_to_dataset)

pictures = []

print("Getting images from folder")
with os.scandir(path_to_dataset) as files:
  for file in files:
    if file.name.endswith(".jpg"):
      pictures.append(file.name)
# Out:
# Getting images from folder

# %%
print(len(pictures))
# Out:
# 5000

# %% [markdown]
# Initialize ResNet Model
